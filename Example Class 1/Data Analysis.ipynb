# %% [markdown]
# # Project 1
# # Integration of Mergesort & Insertion Sort

# %%
import time
import math
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# ### c) Analyze Time Complexity

# %%
FixedSData = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/excelType2.csv',header=0)

# %%
FixedSData.head
# Out:
# <bound method NDFrame.head of               Algorithm  Array Size  Threshold Size  Key Comparisons  \
# 0  Merge-Insertion Sort        1000              40            13573
# 1  Merge-Insertion Sort       10000              40           182907
# 2  Merge-Insertion Sort      100000              40          1862513
# 3  Merge-Insertion Sort     1000000              40         23193928
# 4  Merge-Insertion Sort    10000000              40        281253639
#
#    Execution Time    Worst case     Best Case
# 0        0.000211  4.139794e+04  2.397940e+03
# 1        0.002134  4.239794e+05  3.397940e+04
# 2        0.020033  4.339794e+06  4.397940e+05
# 3        0.183953  4.439794e+07  5.397940e+06
# 4        2.060499  4.539794e+08  6.397940e+07  >

# %% [markdown]
# ### C)i) With the value of S fixed, plot the number of key comparisons over different sizes of the input list n. Compare your empirical results with your theoretical analysis of the time complexity.

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= FixedSData, x="Array Size", y="Key Comparisons", label="Hybrid Merge-Insertion Sort")
plot = sb.lineplot(data= FixedSData, x="Array Size", y = "Best Case", label="Best Case Theorectical Hybrid Merge-Insertion Sort")
plot = sb.lineplot(data= FixedSData, x="Array Size",y = "Worst case", label="Worst Case Theorectical Hybrid Merge-Insertion Sort")
plot.set(title="Number of Key Comparisons over different Array Size with fixed threshhold value of 40. ")
# Out:
# [Text(0.5, 1.0, 'Number of Key Comparisons over different Array Size with fixed threshhold value of 40. ')]

# %%
FixedNData = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/excelType3.csv',header=0)

# %%
FixedNData.head
# Out:
# <bound method NDFrame.head of                 Algorithm  Array Size  Threshold Size  Key Comparisons  \
# 0    Merge-Insertion Sort     1000000               0         18673132
# 1    Merge-Insertion Sort     1000000               1         18674555
# 2    Merge-Insertion Sort     1000000               2         18674555
# 3    Merge-Insertion Sort     1000000               3         18674530
# 4    Merge-Insertion Sort     1000000               4         18728567
# ..                    ...         ...             ...              ...
# 96   Merge-Insertion Sort     1000000              96         29887164
# 97   Merge-Insertion Sort     1000000              97         29887164
# 98   Merge-Insertion Sort     1000000              98         29887164
# 99   Merge-Insertion Sort     1000000              99         29877573
# 100  Merge-Insertion Sort     1000000             100         29877573
#
#      Execution Time    Worst Case    Best Case
# ...

# %% [markdown]
# ### C)ii) With the input size n fixed, plot the number of key comparisons over different values of S. Compare your empirical results with your theoretical analysis of the time complexity.

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= FixedNData, x="Threshold Size", y = "Key Comparisons", label="Hybrid Merge-Insertion Sort")
plot = sb.lineplot(data= FixedNData, x="Threshold Size", y = "Best Case", label="Best Case Theorectical Hybrid Merge-Insertion Sort")
plot = sb.lineplot(data= FixedNData, x="Threshold Size", y = "Worst Case", label="Worst Case Theorectical Hybrid Merge-Insertion Sort")
plot.set(title="Number of Key Comparisons over different threshold values with fixed input size of 1000000. ")
# Out:
# [Text(0.5, 1.0, 'Number of Key Comparisons over different threshold values with fixed input size of 1000000. ')]

# %% [markdown]
# ### C)iii) Using different sizes of input datasets, study how to determine anoptimal value of S for the best performance of this hybrid algorithm.

# %%
N1000 = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/excelType4.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= N1000, x="Threshold Size", y="Execution Time", label="Hybrid Merge-Insertion Sort")
plot.set(title="Execution time over different threshold values with fixed input size of 1000. ")
# Out:
# [Text(0.5, 1.0, 'Execution time over different threshold values with fixed input size of 1000. ')]

# %% [markdown]
# Through our data, we concluded that the execution time was the fastest when S = 60 for a fixed input size of 1000.

# %%
N10000 = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/excelType5.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= N10000, x="Threshold Size", y="Execution Time", label="Hybrid Merge-Insertion Sort")
plot.set(title="Execution time over different threshold values with fixed input size of 10000. ")
# Out:
# [Text(0.5, 1.0, 'Execution time over different threshold values with fixed input size of 10000. ')]

# %% [markdown]
# Through our data, we concluded that the execution time was the fastest when S = 38 for a fixed input size of 10000.

# %%
N100000 = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/excelType6.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= N100000, x="Threshold Size", y="Execution Time", label="Hybrid Merge-Insertion Sort")
plot.set(title="Execution time over different threshold values with fixed input size of 100000. ")
# Out:
# [Text(0.5, 1.0, 'Execution time over different threshold values with fixed input size of 100000. ')]

# %% [markdown]
# Through our data, we concluded that the execution time was the fastest when S = 27 for a fixed input size of 100000.

# %%
N1000000 = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/excelType7.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= N1000000, x="Threshold Size", y="Execution Time", label="Hybrid Merge-Insertion Sort")
plot.set(title="Execution time over different threshold values with fixed input size of 1000000. ")
# Out:
# [Text(0.5, 1.0, 'Execution time over different threshold values with fixed input size of 1000000. ')]

# %% [markdown]
# Through our data, we concluded that the execution time was the fastest when S = 23 for a fixed input size of 1000000.

# %%
N10000000 = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/excelType8.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= N10000000, x="Threshold Size", y="Execution Time", label="Hybrid Merge-Insertion Sort")
plot.set(title="Execution time over different threshold values with fixed input size of 10000000. ")
# Out:
# [Text(0.5, 1.0, 'Execution time over different threshold values with fixed input size of 10000000. ')]

# %% [markdown]
# Through our data, we concluded that the execution time was the fastest when S = 19 for a fixed input size of 1000000.

# %% [markdown]
# However, individual optimal value of S for each data input size does not help with finding the optimal for different sizes of input datasets. Hence, we decided to find the average execution time for different dataset for each individual S value from 0-100 to find the optimal S value.

# %%
OptimalS = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/OptimalS.csv',header=0)

# %%
OptimalS.head()
# Out:
#    Threshold Size      1000      2500      5000      7500     10000     25000  \
# 0               0  0.001016  0.002964  0.004879  0.007514  0.008186  0.020210
# 1               1  0.000483  0.001613  0.002611  0.004085  0.005364  0.010421
# 2               2  0.000475  0.001128  0.002172  0.002880  0.003592  0.007683
# 3               3  0.000435  0.000893  0.001576  0.002658  0.003255  0.006051
# 4               4  0.000288  0.000865  0.001553  0.002329  0.003086  0.005172
#
#       50000     75000    100000    250000    500000    750000   1000000  \
# 0  0.035605  0.047687  0.038192  0.107660  0.175296  0.223843  0.322589
# 1  0.017119  0.021613  0.021637  0.052481  0.108070  0.163292  0.223980
# 2  0.012263  0.014679  0.017768  0.043484  0.090748  0.142791  0.188475
# 3  0.008959  0.012231  0.014948  0.042697  0.088749  0.126888  0.183843
# 4  0.008152  0.011340  0.014925  0.037015  0.077614  0.127387  0.163372
#
#     2500000   5000000   7500000  10000000     Total   Average
# ...

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= OptimalS, x="Threshold Size", y="Average", label="Hybrid Merge-Insertion Sort")
plot.set(title="Average Execution time over different threshold values with input size range from 1000 to 10000000. ")
# Out:
# [Text(0.5, 1.0, 'Average Execution time over different threshold values with input size range from 1000 to 10000000. ')]

# %% [markdown]
# Through our data, we found out that the optimal value of S for the best performance of this hybrid algorithm is 36!

# %%
HybridvsMerge = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 1/Merge_Insertion_Sort/Merge_Insertion_Sort/HybridvsMerge.csv',header=0)

# %% [markdown]
# ### D)Compare with original Mergesort: Implement the original version of Mergesort (as learnt in lecture). Compare its performance against the above hybrid algorithm in terms of the number of key comparisons and CPU times on the dataset with 10 million integers. You can use the optimal value of S obtained in (c) for this task.

# %%
plt.figure(figsize=(10,5))
plot = sb.barplot(data= HybridvsMerge, x="Key Comparisons", y="Algorithm", label="Hybrid vs Merge Sort")
plot.set(title="Number of Key Comparisons with 10 million integer dataset and optimal S value of 36.")
# Out:
# [Text(0.5, 1.0, 'Number of Key Comparisons with 10 million integer dataset and optimal S value of 36.')]

# %%
plt.figure(figsize=(10,5))
plot = sb.barplot(data= HybridvsMerge, x="Execution Time", y="Algorithm", label="Hybrid vs Merge Sort")
plot.set(title="CPU Times with 10 million integer dataset and optimal S value of 36.")
# Out:
# [Text(0.5, 1.0, 'CPU Times with 10 million integer dataset and optimal S value of 36.')]
