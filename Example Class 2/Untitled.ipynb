# %% [markdown]
# # Project 2
# # The Dijkstra’s Algorithm

# %%
import time
import math
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
TheoryGraph = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TheoryTimeAnalysisMatrix.csv',header=0)

# %% [markdown]
# #### a) Suppose the input graph G = (V, E) is stored in an adjacency matrix and we use an array for the priority queue. Implement the Dijkstra’s algorithm using this setting and analyze its time complexity with respect to |V| and |E| both theoretically and empirically.

# %%
FullGraph = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TimeanalysisFullGraphDifferent|V|.csv',header=0)

# %%
FullGraph.head()
# Out:
#    Number of vertices  Number of edges  Time in nanoseconds  Time in seconds  \
# 0                   4               12               615956         0.000616
# 1                   5               20               217302         0.000217
# 2                   6               30               308102         0.000308
# 3                   7               42               352733         0.000353
# 4                   8               56               409108         0.000409
#
#    Count
# 0     11
# 1     20
# 2     23
# 3     28
# 4     38

# %%
TheoryGraph.head()
# Out:
#    Number Of Vertices   Count
# 0                    4     16
# 1                    5     25
# 2                    6     36
# 3                    7     49
# 4                    8     64

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= FullGraph, x="Number of vertices", y="Count", label="Full Completed Graph")
plot = sb.lineplot(data= TheoryGraph, x="Number Of Vertices ", y="Count", label="Theoretical Graph")
plot.set(title="Increasing Number of vertices on a Full Completed Graph i.e maximum edges on adjacency matrix.")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a Full Completed Graph i.e maximum edges on adjacency matrix.')]

# %%
PartialGraph = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TimeanalysisPartialGraphDifferent|V|.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= PartialGraph, x="Number of vertices", y="Count", label="Partial Graph")
plot = sb.lineplot(data= TheoryGraph, x="Number Of Vertices ", y="Count", label="Theoretical Graph")
plot.set(title="Increasing Number of vertices on a Partial Graph on adjacency matrix. ")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a Partial Graph on adjacency matrix. ')]

# %%
OneGraph = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TimeanalysisOneGraphDifferent|V|.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= OneGraph, x="Number of vertices", y="Count", label="One Graph")
plot = sb.lineplot(data= TheoryGraph, x="Number Of Vertices ", y="Count", label="Theoretical Graph")
plot.set(title="Increasing Number of vertices on a One Graph on adjacency matrix. ")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a One Graph on adjacency matrix. ')]

# %%
BFullGraph = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/BTimeanalysisFullGraphDifferent|V|.csv',header=0)

# %%
BFullGraphTheory = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TheoryTimeAnalysisListFullGraph.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= BFullGraph, x="Number of vertices", y="Count", label="Full Completed Graph")
plot = sb.lineplot(data= BFullGraphTheory, x="Number of vertices ", y="Count", label="Theoretical Full Completed Graph")

plot.set(title="Increasing Number of vertices on a Full Completed Graph i.e maximum edges on adjacency lists.")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a Full Completed Graph i.e maximum edges on adjacency lists.')]

# %%
BPartialGraph = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/BTimeanalysisPartialGraphDifferent|V|.csv',header=0)

# %%
PartialGraphTheory = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TheoryTimeAnalysisListPartialGraph.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= BPartialGraph, x="Number of vertices", y="Count", label="Partial Graph")
plot = sb.lineplot(data= PartialGraphTheory, x="Number of vertices", y="Count", label="Theoretical Partial Graph")
plot.set(title="Increasing Number of vertices on a Partial Graph on adjacency lists. ")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a Partial Graph on adjacency lists. ')]

# %%
BOneGraph = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/BTimeanalysisOneGraphDifferent|V|.csv',header=0)

# %%
OneGraphTheory = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TheoryTimeAnalysisListOneGraph.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= BOneGraph, x="Number of vertices", y="Count", label="One Graph")
plot = sb.lineplot(data= OneGraphTheory, x="Number of vertices", y="Count", label="Theory One Graph")
plot.set(title="Increasing Number of vertices on a One Graph on adjacency lists. ")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a One Graph on adjacency lists. ')]

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= FullGraph, x="Number of vertices", y="Count", label="Matrix Full Graph")
plot = sb.lineplot(data= BFullGraph, x="Number of vertices", y="Count", label="List Full Graph")
plot.set(title="Increasing Number of vertices on a full graph. Matrix vs List")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a full graph. Matrix vs List')]

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= PartialGraph, x="Number of vertices", y="Count", label="Matrix Partial Graph")
plot = sb.lineplot(data= BPartialGraph, x="Number of vertices", y="Count", label="List Partial Graph")
plot.set(title="Increasing Number of vertices on a Partial graph. Matrix vs List")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a Partial graph. Matrix vs List')]

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= OneGraph, x="Number of vertices", y="Count", label="Matrix One Graph")
plot = sb.lineplot(data= BOneGraph, x="Number of vertices", y="Count", label="List One Graph")
plot.set(title="Increasing Number of vertices on a One graph. Matrix vs List")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of vertices on a One graph. Matrix vs List')]

# %%
FullGraphDifferentE = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TimeanalysisFullGraphDifferent|E|.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= FullGraphDifferentE, x="Number of edges", y="Count", label="Matrix Graph")
plot = sb.lineplot(data= FullGraphDifferentE, x="Number of edges", y="Theory Count", label="Theory Graph")
plot.set(title="Increasing Number of Edges on a 100 vertices graph using adjacency matrix and array ")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of Edges on a 100 vertices graph using adjacency matrix and array ')]

# %%
BFullGraphDifferentE = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/BTimeanalysisFullGraphDifferent|E|.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= BFullGraphDifferentE, x="Number of edges", y="Count", label="List Graph")
plot = sb.lineplot(data= BFullGraphDifferentE, x="Number of edges", y="Theory Count", label="Theory Graph")
plot.set(title="Increasing Number of Edges on a 100 vertices graph using list and heap")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of Edges on a 100 vertices graph using list and heap')]

# %%
TimeComparisonAB = pd.read_csv('/Users/zisuan/Desktop/SC2001/Example Class 2/TimeComparisonDifferent|E|.csv',header=0)

# %%
plt.figure(figsize=(15,5))
plot = sb.lineplot(data= TimeComparisonAB, x="Number of edges", y="Count Matrix", label="Matrix Graph")
plot = sb.lineplot(data= TimeComparisonAB, x="Number of edges", y="Count List", label="List Graph")
plt.ylabel("Count")
plot.set(title="Increasing Number of Edges on a 100 vertices graph Matrix vs List")
# Out:
# [Text(0.5, 1.0, 'Increasing Number of Edges on a 100 vertices graph Matrix vs List')]
